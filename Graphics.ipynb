# %% [markdown]
# <a href="https://colab.research.google.com/github/Bilol2747/python_darslarim/blob/main/Graphics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
pip install seaborn

# %%
df=pd.read_csv("https://github.com/anvarnarz/praktikum_datasets/raw/main/museum_visitors.csv", index_col=0)
df.head()
# Out:
#             Avila Adobe  Firehouse Museum  Chinese American Museum  \
# Date
# 2014-01-01        24778              4486                     1581
# 2014-02-01        18976              4172                     1785
# 2014-03-01        25231              7082                     3229
# 2014-04-01        26989              6756                     2129
# 2014-05-01        36883             10858                     3676
#
#             America Tropical Interpretive Center
# Date
# 2014-01-01                                  6602
# 2014-02-01                                  5029
# 2014-03-01                                  8129
# 2014-04-01                                  2824
# 2014-05-01                                 10694

# %%
df.shape
# Out:
# (59, 4)

# %%
sns.lineplot(data=df)
plt.show()

# %%
plt.plot(df)
plt.show()

# %%
plt.figure(figsize=(16,6))
plt.title("Muzeylarga tashrif soni")
plt.xlabel('Sana')
plt.ylabel("Odamlar soni")
plt.xticks(rotation=90)
plt.grid()
sns.lineplot(data=df)
plt.show()

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv("https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/uzbekistan.csv", index_col=0)
df.columns = ['maydon','aholi']
df
# Out:
#                                  maydon      aholi
# Boʻlinishi
# Andijon viloyati                 4200.0  1899000.0
# Buxoro viloyati                 39400.0  1384700.0
# Fargʻona viloyati                6800.0  2597000.0
# Jizzax viloyati                 20500.0   910500.0
# Xorazm viloyati                  6300.0  1200000.0
# Namangan viloyati                7900.0  1862000.0
# Navoiy viloyati                110800.0   767500.0
# Qashqadaryo viloyati            28400.0  2029000.0
# Qoraqalpogʻiston Respublikasi  160000.0  1200000.0
# Samarqand viloyati              16400.0  2322000.0
# Sirdaryo viloyati                5100.0   648100.0
# Surxondaryo viloyati            20800.0  1676000.0
# Toshkent viloyati               15300.0  4450000.0

# %%
plt.figure(figsize=(16,6))
sns.barplot(x=df.index, y=df['aholi'])
plt.title("O'zbekiston Respiblikasi aholi soni")
plt.xlabel('Hudud')
plt.ylabel('Aholi soni')
plt.grid()
plt.xticks(rotation=90)
plt.show()

# %%
df=pd.read_csv("https://github.com/anvarnarz/praktikum_datasets/raw/main/museum_visitors.csv", index_col=0, parse_dates, usecols=[0, 1])
df.head()
# Out:
#             Avila Adobe
# Date
# 2014-01-01        24778
# 2014-02-01        18976
# 2014-03-01        25231
# 2014-04-01        26989
# 2014-05-01        36883

# %%
type(df.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
df['month']= [i.month for i in df.index]
df.head()
# Out:
#             Avila Adobe  month
# Date
# 2014-01-01        24778      1
# 2014-02-01        18976      2
# 2014-03-01        25231      3
# 2014-04-01        26989      4
# 2014-05-01        36883      5

# %%
df['year']=[i.year for i in df.index]
df.head()
# Out:
#             Avila Adobe  month  year
# Date
# 2014-01-01        24778      1  2014
# 2014-02-01        18976      2  2014
# 2014-03-01        25231      3  2014
# 2014-04-01        26989      4  2014
# 2014-05-01        36883      5  2014

# %%
df2=df.groupby(['month', 'year']).max()
df2
# Out:
#             Avila Adobe
# month year
# 1     2014        24778
#       2015        20438
#       2016        19659
#       2017        18792
#       2018        16265
# 2     2014        18976
#       2015        15578
#       2016        17378
#       2017        14035
#       2018        14718
# 3     2014        25231
#       2015        21297
#       2016        20322
#       2017        20680
#       2018        19001
# 4     2014        26989
#       2015        26670
#       2016        24521
#       2017        25234
#       2018        18966
# 5     2014        36883
#       2015        34383
#       2016        31728
#       2017        30029
#       2018        25173
# 6     2014        29487
#       2015        30569
#       2016        23696
#       2017        22169
#       2018        22171
# 7     2014        32378
#       2015        41242
#       2016        31689
#       2017        30831
#       2018        23136
# 8     2014        37680
# ...

# %%
df2.unstack(level=1)
# Out:
#       Avila Adobe
# year         2014     2015     2016     2017     2018
# month
# 1         24778.0  20438.0  19659.0  18792.0  16265.0
# 2         18976.0  15578.0  17378.0  14035.0  14718.0
# 3         25231.0  21297.0  20322.0  20680.0  19001.0
# 4         26989.0  26670.0  24521.0  25234.0  18966.0
# 5         36883.0  34383.0  31728.0  30029.0  25173.0
# 6         29487.0  30569.0  23696.0  22169.0  22171.0
# 7         32378.0  41242.0  31689.0  30831.0  23136.0
# 8         37680.0  30700.0  25987.0  27009.0  20815.0
# 9         28473.0  20967.0  22897.0  23403.0  21020.0
# 10        27995.0  29764.0  25040.0  22164.0  19280.0
# 11        25691.0  24483.0  17760.0  17629.0  17163.0
# 12        18754.0  21426.0  20107.0  18339.0      NaN

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
plt.figure(figsize=(12,6))
sns.heatmap(data=df2.unstack(level=0), cmap='Accent', linewidths=2, square=True)
plt.show()

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv("https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/merc.csv")
df.head()
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 0        SLK  2005   5200    Automatic    63000   Petrol  325  32.1
# 1    S Class  2017  34948    Automatic    27000   Hybrid   20  61.4
# 2   SL CLASS  2016  49948    Automatic     6200   Petrol  555  28.0
# 3    G Class  2016  61948    Automatic    16000   Petrol  325  30.4
# 4    G Class  2016  73948    Automatic     4000   Petrol  325  30.1
#
#    engineSize
# 0         1.8
# 1         2.1
# 2         5.5
# 3         4.0
# 4         4.0

# %%
df.shape
# Out:
# (13119, 9)

# %%
df=df[df['year']>2000]
plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='year', y='price')
plt.show()

# %%
df=df[df['year']>2000]
plt.figure(figsize=(10,6))
##sns.scatterplot(data=df, x='year', y='price')
sns.regplot(data=df, x='year', y='price')
plt.show()

# %%
df=df[df['year']>2000]
plt.figure(figsize=(16,8))
sns.scatterplot(data=df, x='mileage', y='price', style='fuelType', hue= 'transmission', s=80)
#sns.regplot(data=df, x='mileage', y='price')
plt.show()

# %%
df=pd.read_csv("https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/merc.csv")
df.head()
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 0        SLK  2005   5200    Automatic    63000   Petrol  325  32.1
# 1    S Class  2017  34948    Automatic    27000   Hybrid   20  61.4
# 2   SL CLASS  2016  49948    Automatic     6200   Petrol  555  28.0
# 3    G Class  2016  61948    Automatic    16000   Petrol  325  30.4
# 4    G Class  2016  73948    Automatic     4000   Petrol  325  30.1
#
#    engineSize
# 0         1.8
# 1         2.1
# 2         5.5
# 3         4.0
# 4         4.0

# %%
df=df[df.year>2010]
df=df[df.transmission!='other']
df=df[df.fuelType!='other']
df.head()
# Out:
#        model  year   price transmission  mileage fuelType  tax   mpg  \
# 1    S Class  2017   34948    Automatic    27000   Hybrid   20  61.4
# 2   SL CLASS  2016   49948    Automatic     6200   Petrol  555  28.0
# 3    G Class  2016   61948    Automatic    16000   Petrol  325  30.4
# 4    G Class  2016   73948    Automatic     4000   Petrol  325  30.1
# 5   SL CLASS  2011  149948    Automatic     3000   Petrol  570  21.4
#
#    engineSize
# 1         2.1
# 2         5.5
# 3         4.0
# 4         4.0
# 5         6.2

# %%
plt.figure(figsize=(10,6))
sns.histplot(data=df, x='price')
plt.show()

# %%
sns.displot(data=df, x='price', height=5, hue='transmission',aspect=2)
plt.show()

# %%
sns.displot(data=df, x='price', height=8, col='transmission',aspect=2)
plt.show()

# %%
sns.displot(data=df, x='price', kind='kde', height=5, aspect=2)
plt.show()

# %%
sns.displot(data=df, x='price', kde=True, hue='fuelType', height=5, aspect=2)
plt.show()

# %%
sns.displot(data=df, x='price', kind='ecdf', height=5, aspect=2)
plt.grid(which='both')
plt.minorticks_on()
plt.show()

# %%
df=pd.read_csv("https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/merc.csv")
df=df[df.year>2010]
df=df[df.transmission!='other']
df=df[df.fuelType!='other']
df.head()
# Out:
#        model  year   price transmission  mileage fuelType  tax   mpg  \
# 1    S Class  2017   34948    Automatic    27000   Hybrid   20  61.4
# 2   SL CLASS  2016   49948    Automatic     6200   Petrol  555  28.0
# 3    G Class  2016   61948    Automatic    16000   Petrol  325  30.4
# 4    G Class  2016   73948    Automatic     4000   Petrol  325  30.1
# 5   SL CLASS  2011  149948    Automatic     3000   Petrol  570  21.4
#
#    engineSize
# 1         2.1
# 2         5.5
# 3         4.0
# 4         4.0
# 5         6.2

# %%
sns.histplot(data=df, x='price')
plt.show()

# %%
sns.scatterplot(data=df, x='price', y='year')
plt.show()

# %%
fig, ax =plt.subplots(2,1, figsize=(10,10))
sns.histplot(ax=ax[0],data=df, x='price')
sns.scatterplot(ax=ax[1],data=df, x='price', y='year')
plt.show()

# %%
pip install lux-api

# %%
from google.colab import output
output.enable_custom_widget_manager()

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_5.groupby('fuelType').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
import lux

# %%
df=pd.read_csv("https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/merc.csv")
df=df[df.year>2010]
df=df[df.transmission!='other']
df=df[df.fuelType!='other']
df['year']= pd.to_datetime(df['year'], format='%Y')
df.head()
# Out:
# /usr/local/lib/python3.11/dist-packages/lux/executor/PandasExecutor.py:548: UserWarning:Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# /usr/local/lib/python3.11/dist-packages/lux/executor/PandasExecutor.py:567: UserWarning:Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# /usr/local/lib/python3.11/dist-packages/lux/executor/PandasExecutor.py:548: UserWarning:Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# ...

# %%
df.intent= ["price", "mileage"]
df
# Out:
# /usr/local/lib/python3.11/dist-packages/lux/core/groupby.py:29: FutureWarning:The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# /usr/local/lib/python3.11/dist-packages/lux/core/groupby.py:29: FutureWarning:The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# /usr/local/lib/python3.11/dist-packages/IPython/core/formatters.py:918: UserWarning:
# Unexpected error in rendering Lux widget and recommendations. Falling back to Pandas display.
# Please report the following issue on Github: https://github.com/lux-org/lux/issues
#
# /usr/local/lib/python3.11/dist-packages/lux/core/frame.py:632: UserWarning:Traceback (most recent call last):
# ...
