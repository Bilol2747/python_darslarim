# %% [markdown]
# <a href="https://colab.research.google.com/github/Bilol2747/python_darslarim/blob/main/04_VISUAL_AMALIYOT_02_seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Imgur](https://i.imgur.com/5pXzCIu.png)
#
# # Data Science va Sun'iy Intellekt Praktikum
#
# ## 4-MODUL. VIZUALIZASIYA
#
# ## 2-AMALIYOT. `seaborn`

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### 1-VAZIFA. Avvalgi [amaliyotda](https://colab.research.google.com/drive/1jzhJ1gN6msILYOHaG2fhBBvUGaa4tcLf?usp=sharing) saqlangan faylni yangi `df`ga o'qing

# %%
#JAVOBINGIZNI SHU YERGA YOZING

# %%
df=pd.read_csv("https://github.com/anvarnarz/praktikum_datasets/raw/main/museum_visitors.csv", index_col=0, parse_dates=[0])
df.head()
# Out:
#             Avila Adobe  Firehouse Museum  Chinese American Museum  \
# Date
# 2014-01-01        24778              4486                     1581
# 2014-02-01        18976              4172                     1785
# 2014-03-01        25231              7082                     3229
# 2014-04-01        26989              6756                     2129
# 2014-05-01        36883             10858                     3676
#
#             America Tropical Interpretive Center
# Date
# 2014-01-01                                  6602
# 2014-02-01                                  5029
# 2014-03-01                                  8129
# 2014-04-01                                  2824
# 2014-05-01                                 10694

# %% [markdown]
# ### 2-VAZIFA. `df` barcha ustunlarini chiziqli grafik ko'rinishida chiqaring

# %%
#JAVOBINGIZNI SHU YERGA YOZING
plt.figure(figsize=(16,6))
sns.lineplot(data=df)
plt.title("Muzeylarga tashriflar soni")
plt.xlabel("sana")
plt.ylabel("Odamlar soni")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# ### 3-VAZIFA. Grafiklar nomini to'g'rilang (`T`, `Tm` va hokazo matnlarni o'zbek tilida chiqaring.)

# %%
#JAVOBINGIZNI SHU YERGA YOZING

# %%
#@title Kutilgan natija:
labels=["Yillik o'rtacha harorat",
        "Yillik o'rtacha maksimal harorat",
        "Yillik o'rtacha minimal harorat",
        "Yillik o'rtacha shamol tezligi",
        "Yomg'irli kunlar soni",
        "Bo'ronli kunlar soni",
        "Tumanli kunlar soni",
        "To'fonli kunlar soni",
        "Do'l yoqqan kunlar"
        ]

plt.figure(figsize=(16,6))
sns.lineplot(data=df, linewidth=2.0)
plt.title("Toshkent shahri uchun ob havo ko'rsatkichlari")
plt.xlabel("Yil")
plt.ylabel("Harorat")
plt.legend(labels, loc=1)
plt.show()

# %% [markdown]
# ### 4-VAZIFA. Yuqoridagi grafikda turli ko'rsatkichlar aralashib ketdi. Keling ustun turiga qarab alohida grafiklar chizamiz.
#
# #### 4.1. Haroratni ko'rsatuvchi ustunlarni alohida chiziqli grafik qilib chiqaring.

# %%
#JAVOBINGIZNI SHU YERGA YOZING
plt.figure(figsize=(16,6))
sns.lineplot(data=df['Avila Adobe'])
plt.title("Muzeylarga tashriflar soni")
plt.xlabel("sana")
plt.ylabel("Odamlar soni")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %%
#@title Kutilgan natija:
labels=["Yillik o'rtacha harorat",
        "Yillik o'rtacha maksimal harorat",
        "Yillik o'rtacha minimal harorat",
        # "Yillik o'rtacha shamol tezligi",
        # "Yomg'irli kunlar soni",
        # "Bo'ronli kunlar soni",
        # "Tumanli kunlar soni",
        # "To'fonli kunlar soni",
        # "Do'l yoqqan kunlar"
        ]

plt.figure(figsize=(16,6))
sns.lineplot(data=df[['T','TM','Tm']], linewidth=2.0)
plt.title("Toshkent shahri uchun ob havo ko'rsatkichlari")
plt.xlabel("Yil")
plt.ylabel("Harorat")
plt.legend(labels, loc=1)
plt.show()

# %% [markdown]
# #### 4.2. Kunlarni ko'rsatuvchi ustunlarni alohida grafik ko'rinishida chiqaring

# %%
#JAVOBINGIZNI SHU YERGA YOZING

# %%
#@title Kutilgan natija:
labels=[
        # "Yillik o'rtacha harorat",
#         "Yillik o'rtacha maksimal harorat",
#         "Yillik o'rtacha minimal harorat",
        # "Yillik o'rtacha shamol tezligi",
        "Yomg'irli kunlar soni",
        "Bo'ronli kunlar soni",
        "Tumanli kunlar soni",
        "To'fonli kunlar soni",
        "Do'l yoqqan kunlar soni"
        ]

plt.figure(figsize=(16,6))
sns.lineplot(data=df[['RA','SN','TS','FG','TN']], linewidth=2.0)
plt.title("Toshkent shahri uchun ob havo ko'rsatkichlari")
plt.xlabel("Yil")
plt.ylabel("Kunlar")
plt.legend(labels, loc=1)
plt.show()

# %% [markdown]
# ### 5-VAZIFA. Yillik o'rtacha shamol tezligini ustunli grafik ko'rinishida chiqaring.

# %%
#JAVOBINGIZNI SHU YERGA YOZING
plt.figure(figsize=(16,3))
sns.barplot(x=df.index, y=df['Avila Adobe'])
plt.title("Muzeylarga tashriflar soni")
plt.xlabel("sana")
plt.ylabel("Odamlar soni")

plt.xticks(rotation=90)

plt.grid()
plt.show()

# %%
#@title Kutilgan natija:
plt.figure(figsize=(16,6))
sns.barplot(x=df.index, y=df['V'])
plt.title("Toshkent shahri uchun ob havo ko'rsatkichlari")
plt.ylabel("O'rtacha shamol tezligi (km/soat)")
plt.xlabel("Yillar")
plt.xticks(rotation=90)
plt.show()

# %%
df.groupby(['Avila Adobe','Date']).max().unstack(level=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-71a1056caa25> in <cell line: 0>()
# ----> 1 df['names']=df[['Avila Adobe',  'Firehouse Museum',     'Chinese American Museum',      'America Tropical Interpretive Center']]
#       2 df.groupby(['Avila Adobe','Date']).max().unstack(level=0)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    4299             self._setitem_array(key, value)
#    4300         elif isinstance(value, DataFrame):
# -> 4301             self._set_item_frame_value(key, value)
#    4302         elif (
#    4303             is_list_like(value)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in _set_item_frame_value(self, key, value)
#    4457
#    4458         if len(value.columns) > 1:
# -> 4459             raise ValueError(
#    4460                 "Cannot set a DataFrame with multiple columns to the single "
#    4461                 f"column {key}"
#
# ValueError: Cannot set a DataFrame with multiple columns to the single column names

# %% [markdown]
# ### 6-VAZIFA. Yomg'rili, qorli, bo'ronli, tumanli va do'l yoqqan kunlar sonini heatmap ko'rinishida chiqaring.

# %%
#JAVOBINGIZNI SHU YERGA YOZING
plt.figure(figsize=(16,3))
sns.heatmap(data=df, cmap='Accent', square=True)
plt.title("Muzeylarga tashriflar soni")
plt.xlabel("sana")
plt.ylabel("Odamlar soni")

plt.xticks(rotation=90)

plt.grid()
plt.show()

# %%
#@title Kutilgan natija:
plt.figure(figsize=(30,5))
sns.heatmap(data=df[['RA','SN','TS','FG','GR']].T, cmap="YlGnBu", linewidths=1, square=True)
plt.title("Toshkent shahri uchun ob havo ko'rsatkichlari")
yticks_labels = ["Yomg'ir","Qor","Bo'ron","Tuman","Do'l"]
plt.yticks(np.arange(5)+0.5, labels=yticks_labels)
plt.xticks(rotation=90)
plt.yticks(rotation=0)
plt.show()
