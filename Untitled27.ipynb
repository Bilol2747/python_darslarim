# %% [markdown]
# <a href="https://colab.research.google.com/github/Bilol2747/python_darslarim/blob/main/Untitled27.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
# !git clone https://github.com/MansurCompAI/Practicum_Datasets.git
# Out:
# fatal: destination path 'Practicum_Datasets' already exists and is not an empty directory.

# %%
movies= pd.read_csv("/content/Practicum_Datasets/IMDb/IMDb_movies.csv")
movies.head()
# Out:
# <ipython-input-43-05575b24f244>:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   movies= pd.read_csv("/content/Practicum_Datasets/IMDb/IMDb_movies.csv")
#   imdb_title_id                        title               original_title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2     tt0001892               Den sorte drøm               Den sorte drøm
# 3     tt0002101                    Cleopatra                    Cleopatra
# 4     tt0002130                    L'Inferno                    L'Inferno
#
#    year date_published                      genre  duration           country  \
# 0  1894     1894-10-09                    Romance        45               USA
# 1  1906     1906-12-26    Biography, Crime, Drama        70         Australia
# 2  1911     1911-08-19                      Drama        53  Germany, Denmark
# ...

# %%
movies.shape
# Out:
# (85855, 15)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85855 entries, 0 to 85854
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   imdb_title_id       85855 non-null  object
#  1   title               85855 non-null  object
#  2   original_title      85855 non-null  object
#  3   year                85855 non-null  object
#  4   date_published      85855 non-null  object
#  5   genre               85855 non-null  object
#  6   duration            85855 non-null  int64
#  7   country             85791 non-null  object
#  8   language            84954 non-null  object
#  9   director            85768 non-null  object
#  10  writer              84283 non-null  object
#  11  production_company  81400 non-null  object
#  12  actors              85786 non-null  object
#  13  description         83740 non-null  object
#  14  budget              23710 non-null  object
# dtypes: int64(1), object(14)
# ...

# %%
ratings= pd.read_csv("/content/Practicum_Datasets/IMDb/IMDb_ratings.csv")
ratings.head()
# Out:
#   imdb_title_id  weighted_average_vote  total_votes
# 0     tt0000009                    5.9          154
# 1     tt0000574                    6.1          589
# 2     tt0001892                    5.8          188
# 3     tt0002101                    5.2          446
# 4     tt0002130                    7.0         2237

# %%
ratings.describe()
# Out:
#        weighted_average_vote   total_votes
# count           85855.000000  8.585500e+04
# mean                5.898656  9.493490e+03
# std                 1.234987  5.357436e+04
# min                 1.000000  9.900000e+01
# 25%                 5.200000  2.050000e+02
# 50%                 6.100000  4.840000e+02
# 75%                 6.800000  1.766500e+03
# max                 9.900000  2.278845e+06

# %%
pd.merge?

# %%
movies.head(2)
# Out:
#   imdb_title_id                        title               original_title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
#
#    year date_published                    genre  duration    country language  \
# 0  1894     1894-10-09                  Romance        45        USA      NaN
# 1  1906     1906-12-26  Biography, Crime, Drama        70  Australia      NaN
#
#           director           writer          production_company  \
# 0  Alexander Black  Alexander Black  Alexander Black Photoplays
# 1     Charles Tait     Charles Tait              J. and N. Tait
#
#                                               actors  \
# 0  Blanche Bayliss, William Courtenay, Chauncey D...
# 1  Elizabeth Tait, John Tait, Norman Campbell, Be...
#
#                                          description  budget
# 0  The adventures of a female reporter in the 1890s.     NaN
# ...

# %%
ratings.head()
# Out:
#   imdb_title_id  weighted_average_vote  total_votes
# 0     tt0000009                    5.9          154
# 1     tt0000574                    6.1          589
# 2     tt0001892                    5.8          188
# 3     tt0002101                    5.2          446
# 4     tt0002130                    7.0         2237

# %%
movies_ratings=pd.merge(movies, ratings)
movies_ratings.head(3)
# Out:
#   imdb_title_id                        title               original_title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2     tt0001892               Den sorte drøm               Den sorte drøm
#
#    year date_published                    genre  duration           country  \
# 0  1894     1894-10-09                  Romance        45               USA
# 1  1906     1906-12-26  Biography, Crime, Drama        70         Australia
# 2  1911     1911-08-19                    Drama        53  Germany, Denmark
#
#   language         director                                 writer  \
# 0      NaN  Alexander Black                        Alexander Black
# 1      NaN     Charles Tait                           Charles Tait
# 2      NaN        Urban Gad  Urban Gad, Gebhard Schätzler-Perasini
#
#            production_company  \
# 0  Alexander Black Photoplays
# ...

# %%
movies_ratings.columns
# Out:
# Index(['imdb_title_id', 'title', 'original_title', 'year', 'date_published',
#        'genre', 'duration', 'country', 'language', 'director', 'writer',
#        'production_company', 'actors', 'description', 'budget',
#        'weighted_average_vote', 'total_votes'],
#       dtype='object')

# %%
sliced= movies_ratings[[ 'title',   'year',   'weighted_average_vote']]
sliced
# Out:
#                                 title  year  weighted_average_vote
# 0                          Miss Jerry  1894                    5.9
# 1         The Story of the Kelly Gang  1906                    6.1
# 2                      Den sorte drøm  1911                    5.8
# 3                           Cleopatra  1912                    5.2
# 4                           L'Inferno  1911                    7.0
# ...                               ...   ...                    ...
# 85850                         Le lion  2020                    5.3
# 85851  De Beentjes van Sint-Hildegard  2020                    7.7
# 85852       Padmavyuhathile Abhimanyu  2019                    7.9
# 85853               Sokagin Çocuklari  2019                    6.4
# 85854      La vida sense la Sara Amat  2019                    6.7
#
# [85855 rows x 3 columns]

# %%
A = pd.DataFrame({'Transport': ['poezd', 'avtomabil', 'kema'],
                  'Tezligi':['70', '180', '45']})

A
# Out:
#    Transport Tezligi
# 0      poezd      70
# 1  avtomabil     180
# 2       kema      45

# %%
B = pd.DataFrame({'Transport': ['poezd', 'avtomabil', 'tramvay'],
                  'Narxi':['98000', '10000', '65000']})

B
# Out:
#    Transport  Narxi
# 0      poezd  98000
# 1  avtomabil  10000
# 2    tramvay  65000

# %%
merged=pd.merge(A, B)
merged
# Out:
#    Transport Tezligi  Narxi
# 0      poezd      70  98000
# 1  avtomabil     180  10000

# %%
merged_outer=pd.merge(A, B, how='outer')
merged_outer
# Out:
#    Transport Tezligi  Narxi
# 0  avtomabil     180  10000
# 1       kema      45    NaN
# 2      poezd      70  98000
# 3    tramvay     NaN  65000

# %%
 merged_left=pd.merge(A, B, how='left')
 merged_left
# Out:
#    Transport Tezligi  Narxi
# 0      poezd      70  98000
# 1  avtomabil     180  10000
# 2       kema      45    NaN

# %%
merged_right=pd.merge(A, B, how='right')
merged_right
# Out:
#    Transport Tezligi  Narxi
# 0      poezd      70  98000
# 1  avtomabil     180  10000
# 2    tramvay     NaN  65000

# %%
A = pd.DataFrame({'Transport_turi': ['poezd', 'avtomabil', 'kema'],
                  'Tezligi':['70', '180', '45']})

A
# Out:
#   Transport_turi Tezligi
# 0          poezd      70
# 1      avtomabil     180
# 2           kema      45

# %%
merged=pd.merge(A, B, left_on='Transport_turi', right_on='Transport')
merged
# Out:
#   Transport_turi Tezligi  Transport  Narxi
# 0          poezd      70      poezd  98000
# 1      avtomabil     180  avtomabil  10000

# %%
A = A.set_index['Transport_turi']
A
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-669560e9dac3> in <cell line: 0>()
# ----> 1 A = A.set_index['Transport_turi']
#       2 A
#
# TypeError: 'method' object is not subscriptable

# %%
A
# Out:
#                Tezligi
# Transport_turi
# poezd               70
# avtomabil          180
# kema                45

# %%
B
# Out:
#    Transport  Narxi
# 0      poezd  98000
# 1  avtomabil  10000
# 2    tramvay  65000

# %%
merged1=pd.merge(A, B, left_index=True, right_on='Transport')
merged1
# Out:
#   Tezligi  Transport  Narxi
# 0      70      poezd  98000
# 1     180  avtomabil  10000

# %%
B=B.set_index('Transport')
B
# Out:
#            Narxi
# Transport
# poezd      98000
# avtomabil  10000
# tramvay    65000

# %%
merg=pd.merge(A, B, left_index=True, right_index=True, how='outer')
merg
# Out:
#           Tezligi  Narxi
# avtomabil     180  10000
# kema           45    NaN
# poezd          70  98000
# tramvay       NaN  65000

# %%
# !git clone https://github.com/MansurCompAI/Practicum_Datasets.git
# Out:
# fatal: destination path 'Practicum_Datasets' already exists and is not an empty directory.

# %%
df=pd.read_csv("/content/Practicum_Datasets/bank.csv", delimiter=";")
df.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4521 entries, 0 to 4520
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        4521 non-null   int64
#  1   job        4521 non-null   object
#  2   marital    4521 non-null   object
#  3   education  4521 non-null   object
#  4   default    4521 non-null   object
#  5   balance    4521 non-null   int64
#  6   housing    4521 non-null   object
#  7   loan       4521 non-null   object
#  8   contact    4521 non-null   object
#  9   day        4521 non-null   int64
#  10  month      4521 non-null   object
#  11  duration   4521 non-null   int64
#  12  campaign   4521 non-null   int64
#  13  pdays      4521 non-null   int64
#  14  previous   4521 non-null   int64
#  15  poutcome   4521 non-null   object
#  16  y          4521 non-null   object
# dtypes: int64(7), object(10)
# memory usage: 600.6+ KB

# %%
bank1, bank2=df[ :2521], df[2521:]

# %%
bank1
# Out:
#       age          job   marital  education default  balance housing loan  \
# 0      30   unemployed   married    primary      no     1787      no   no
# 1      33     services   married  secondary      no     4789     yes  yes
# 2      35   management    single   tertiary      no     1350     yes   no
# 3      30   management   married   tertiary      no     1476     yes  yes
# 4      59  blue-collar   married  secondary      no        0     yes   no
# ...   ...          ...       ...        ...     ...      ...     ...  ...
# 2516   30   management   married   tertiary      no     1882     yes   no
# 2517   48  blue-collar   married    unknown      no      131     yes   no
# 2518   30   technician    single  secondary      no      175      no   no
# 2519   43   technician    single   tertiary     yes        0      no   no
# 2520   38   management  divorced   tertiary      no     4425     yes   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# ...

# %%
bank2
# Out:
#       age            job   marital  education default  balance housing loan  \
# 2521   46     unemployed   married  secondary      no     3533     yes   no
# 2522   59    blue-collar  divorced  secondary      no     3573      no   no
# 2523   44     management  divorced   tertiary      no      476     yes  yes
# 2524   35    blue-collar   married  secondary      no     1257     yes   no
# 2525   55    blue-collar   married    unknown      no       23      no   no
# ...   ...            ...       ...        ...     ...      ...     ...  ...
# 4516   33       services   married  secondary      no     -333     yes   no
# 4517   57  self-employed   married   tertiary     yes    -3313     yes  yes
# 4518   57     technician   married  secondary      no      295      no   no
# 4519   28    blue-collar   married  secondary      no     1137      no   no
# 4520   44   entrepreneur    single   tertiary      no     1136     yes  yes
#
# ...

# %%
pd.concat([bank1, bank2])
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
df1=pd.read_csv("/content/Practicum_Datasets/data_pivot.csv")

# %%
df1
# Out:
#                               date     item      value
# 0    1959-03-31 23:59:59.999999999  realgdp   2710.349
# 1    1959-03-31 23:59:59.999999999     infl      0.000
# 2    1959-03-31 23:59:59.999999999    unemp      5.800
# 3    1959-06-30 23:59:59.999999999  realgdp   2778.801
# 4    1959-06-30 23:59:59.999999999     infl      2.340
# ..                             ...      ...        ...
# 604  2009-06-30 23:59:59.999999999     infl      3.370
# 605  2009-06-30 23:59:59.999999999    unemp      9.200
# 606  2009-09-30 23:59:59.999999999  realgdp  12990.341
# 607  2009-09-30 23:59:59.999999999     infl      3.560
# 608  2009-09-30 23:59:59.999999999    unemp      9.600
#
# [609 rows x 3 columns]

# %%
pivoted_data=df1.pivot('date', 'item', 'value')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-16f91984c8c1> in <cell line: 0>()
# ----> 1 pivoted_data=df1.pivot('date')
#
# TypeError: DataFrame.pivot() takes 1 positional argument but 2 were given

# %%
pivoted_data = df1.pivot('date', 'item', 'value')
pivoted_data
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-65-763bc9e4735b> in <cell line: 0>()
# ----> 1 pivoted_data = df1.pivot('date', 'item', 'value')
#       2 pivoted_data
#
# TypeError: DataFrame.pivot() takes 1 positional argument but 4 were given

# %%
df1['value2']=np.random.randn(len(df1))

# %%
df1
# Out:
#                               date     item      value    value2
# 0    1959-03-31 23:59:59.999999999  realgdp   2710.349 -0.254982
# 1    1959-03-31 23:59:59.999999999     infl      0.000  0.117695
# 2    1959-03-31 23:59:59.999999999    unemp      5.800 -0.571986
# 3    1959-06-30 23:59:59.999999999  realgdp   2778.801  0.016601
# 4    1959-06-30 23:59:59.999999999     infl      2.340  0.403732
# ..                             ...      ...        ...       ...
# 604  2009-06-30 23:59:59.999999999     infl      3.370 -0.900002
# 605  2009-06-30 23:59:59.999999999    unemp      9.200 -0.167495
# 606  2009-09-30 23:59:59.999999999  realgdp  12990.341 -0.940661
# 607  2009-09-30 23:59:59.999999999     infl      3.560  1.038757
# 608  2009-09-30 23:59:59.999999999    unemp      9.600  0.948176
#
# [609 rows x 4 columns]

# %%
df1.pivot(['date', 'item'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-74-2e62be9a3eac> in <cell line: 0>()
# ----> 1 df1.pivot(['date', 'item'])
#
# TypeError: DataFrame.pivot() takes 1 positional argument but 2 were given

# %%
i
